# %% [markdown]
# # Task 1 — Load CSV and Perform Basic EDA

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/loan_data.csv")
print("Shape:", df.shape)
# Out:
# Shape: (310, 8)

# %% [markdown]
# ### Head — first 5 rows

# %%
df.head()
# Out:
#     age   income  loan_amount  credit_score  years_employed    education  \
# 0  50.0  93847.0      42744.0         384.0            10.0     bachelor
# 1  36.0  99634.0      50543.0         350.0            15.0  high_school
# 2  29.0  48251.0      47783.0         645.0             3.0  high_school
# 3  42.0  45945.0      31657.0         669.0            19.0  high_school
# 4  40.0  52217.0      41187.0         755.0             4.0  high_school
#
#          city  approved
# 0  Biratnagar         1
# 1  Biratnagar         1
# 2   Kathmandu         1
# 3   Kathmandu         1
# 4     Pokhara         1

# %% [markdown]
# ### Info — column types and non-null counts

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             300 non-null    float64
#  1   income          298 non-null    float64
#  2   loan_amount     310 non-null    float64
#  3   credit_score    302 non-null    float64
#  4   years_employed  310 non-null    float64
#  5   education       310 non-null    object
#  6   city            310 non-null    object
#  7   approved        310 non-null    int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 19.5+ KB

# %% [markdown]
# ### Describe — summary statistics

# %%
df.describe()
# Out:
#               age         income    loan_amount  credit_score  years_employed  \
# count  300.000000     298.000000     310.000000    302.000000      310.000000
# mean    38.913333   61362.332215   32957.667742    579.586093        9.441935
# std     10.113031   56369.177216   31175.945928    132.675475        5.623130
# min     22.000000   20384.000000    5009.000000      5.000000        0.000000
# 25%     29.000000   40152.250000   17054.500000    472.500000        4.000000
# 50%     40.000000   57460.500000   30053.500000    590.000000        9.500000
# 75%     47.250000   77799.000000   46407.250000    684.750000       14.000000
# max     54.000000  950000.000000  500000.000000    799.000000       19.000000
#
#          approved
# count  310.000000
# mean     0.838710
# std      0.368393
# min      0.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %% [markdown]
# ### Missing values

# %%
df.isnull().sum()
# Out:
# age               10
# income            12
# loan_amount        0
# credit_score       8
# years_employed     0
# education          0
# city               0
# approved           0
# dtype: int64
