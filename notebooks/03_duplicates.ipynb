# %% [markdown]
# # Task 3 — Detect and Remove Duplicate Rows

# %%
import pandas as pd

df = pd.read_csv("../data/loan_data.csv")
print("Shape before:", df.shape)
# Out:
# Shape before: (310, 8)

# %%
# Check how many duplicates
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 10

# %%
# Show some duplicate rows
df[df.duplicated(keep=False)].head(6)
# Out:
#       age   income  loan_amount  credit_score  employment_years    education  \
# 73   38.0  40764.0      22144.0         638.0              11.0       master
# 106  50.0  81476.0      56745.0         592.0              12.0       master
# 123  48.0  99459.0      34721.0         695.0               4.0       master
# 127  29.0  44466.0      27195.0         567.0               5.0     bachelor
# 176  54.0  39870.0      12561.0         785.0              11.0       master
# 185  28.0  29435.0      12943.0         439.0              14.0  high_school
#
#            city  approved
# 73    Kathmandu         1
# 106  Biratnagar         1
# 123  Biratnagar         1
# 127    Lalitpur         0
# 176     Pokhara         1
# 185   Kathmandu         1

# %%
# Remove duplicates
df = df.drop_duplicates()
df = df.reset_index(drop=True)
print("Shape after:", df.shape)
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Shape after: (300, 8)
# Duplicate rows: 0
